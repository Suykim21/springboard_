# %% [markdown]
# # Part 1 ‐ Exploratory data analysis
# The attached logins.json file contains (simulated) timestamps of user logins in a particular geographic location. Aggregate these login counts based on 15-minute time intervals, and visualize and describe the resulting **time series** of login counts in ways that best characterize the underlying patterns of the demand. Please report/illustrate important features of the demand, such as daily cycles. If there are data quality issues, please report them.

# %%
# Essentials
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")
import chart_studio.plotly as py
import plotly.express as px

# %% [markdown]
# ## 1.1 Data Cleaning

# %%
# Get logins file
logins_df = pd.read_json('logins.json')
logins_df.head(3)
# Out:
#            login_time
# 0 1970-01-01 20:13:18
# 1 1970-01-01 20:16:10
# 2 1970-01-01 20:16:37

# %%
logins_df.describe()
# Out:
#                  login_time
# count                 93142
# unique                92265
# top     1970-02-12 11:16:53
# freq                      3
# first   1970-01-01 20:12:16
# last    1970-04-13 18:57:38

# %% [markdown]
# There are multiple logins on February 2nd, 1970 precisely at the same time. Not exactly sure if login records are based on ONE user or multiple users. I'm assuming the login records are based on MULTIPLE users therefore assuming having 3 identical login times as valid.

# %%
logins_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93142 entries, 0 to 93141
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   login_time  93142 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 727.8 KB

# %%
logins_df.isna().sum()
# Out:
# login_time    0
# dtype: int64

# %% [markdown]
# Correct datatype and no missing values.

# %%
logins_df
# Out:
#                login_time
# 0     1970-01-01 20:13:18
# 1     1970-01-01 20:16:10
# 2     1970-01-01 20:16:37
# 3     1970-01-01 20:16:36
# 4     1970-01-01 20:26:21
# ...                   ...
# 93137 1970-04-13 18:50:19
# 93138 1970-04-13 18:43:56
# 93139 1970-04-13 18:54:02
# 93140 1970-04-13 18:57:38
# 93141 1970-04-13 18:54:23
#
# [93142 rows x 1 columns]

# %%
# Sorting by datetime
logins_df = logins_df.sort_values(by='login_time')
logins_df.reset_index(drop=True, inplace=True)
logins_df
# Out:
#                login_time
# 0     1970-01-01 20:12:16
# 1     1970-01-01 20:13:18
# 2     1970-01-01 20:16:10
# 3     1970-01-01 20:16:36
# 4     1970-01-01 20:16:37
# ...                   ...
# 93137 1970-04-13 18:48:52
# 93138 1970-04-13 18:50:19
# 93139 1970-04-13 18:54:02
# 93140 1970-04-13 18:54:23
# 93141 1970-04-13 18:57:38
#
# [93142 rows x 1 columns]

# %% [markdown]
# Sorted by datetime since it was out of order as shown on index 93137, 93138, and 93139.

# %% [markdown]
# ## 1.2 Aggregate these login counts based on 15-minute time intervals (Time Resampling)

# %%
#resampling df to 15-minute intervals
logins_df = logins_df.resample("15min", on="login_time").count()

#cleaning up df
logins_df.index.name = "login_date"
logins_df.reset_index(inplace=True)
logins_df.rename({"login_time":"logins"}, axis=1, inplace=True)

#show
logins_df.head()
# Out:
#            login_date  logins
# 0 1970-01-01 20:00:00       2
# 1 1970-01-01 20:15:00       6
# 2 1970-01-01 20:30:00       9
# 3 1970-01-01 20:45:00       7
# 4 1970-01-01 21:00:00       1

# %%
logins_df.shape
# Out:
# (9788, 2)

# %% [markdown]
# ## 1.3 visualize and describe the resulting time series of login counts in ways that best characterize the underlying patterns of the demand

# %%
fig = px.histogram(logins_df, x="logins", nbins=15)

fig.update_layout(
    title_text ='Distribution of Login Counts',
    xaxis_title_text = '# of logins in 15-min interval',
    yaxis_title_text = 'Count',
    bargap=0.2, # gap etween bars of adjacent location coordinates
)
fig.show()
# Out:
# <div>                            <div id="3d2223fa-3a05-4a28-aef7-9c513a45fc09" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d2223fa-3a05-4a28-aef7-9c513a45fc09")) {                    Plotly.newPlot(                        "3d2223fa-3a05-4a28-aef7-9c513a45fc09",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "logins=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "nbinsx": 15, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [2, 6, 9, 7, 1, 4, 0, 4, 9, 8, 1, 3, 16, 13, 14, 15, 10, 18, 12, 13, 9, 8, 10, 6, 7, 18, 12, 6, 12, 5, 6, 5, 2, 0, 5, 2, 5, 4, 1, 1, 1, 0, 2, 4, 3, 1, 1, 1, 3, 1, 3, 1, 3, 1, 6, 2, 7, 8, 8, 5, 9, 12,
# ...

# %% [markdown]
# Majority of login counts range from 0 to 15.

# %% [markdown]
# ### 1.3.1 Monthly/Weekly/Daily/Hours Logins

# %%
import calendar
days = list(calendar.day_abbr)
months = list(calendar.month_abbr)

# %%
logins_df['month'] = logins_df['login_date'].apply(lambda d: months[d.month])
logins_df['hour'] = logins_df['login_date'].apply(lambda d: d.hour)
logins_df['weekday'] = logins_df['login_date'].apply(lambda d: days[d.weekday()])

# %%
logins_df.head()
# Out:
#            login_date  logins month  hour weekday
# 0 1970-01-01 20:00:00       2   Jan    20     Thu
# 1 1970-01-01 20:15:00       6   Jan    20     Thu
# 2 1970-01-01 20:30:00       9   Jan    20     Thu
# 3 1970-01-01 20:45:00       7   Jan    20     Thu
# 4 1970-01-01 21:00:00       1   Jan    21     Thu

# %%
hour_counts = logins_df.groupby('hour')['logins'].sum()
day_counts = logins_df.groupby('weekday')['logins'].sum()
month_counts = logins_df.groupby('month')['logins'].sum()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(20,4))
sns.barplot(x=day_counts.index, y=day_counts, order=days, ax=ax1).set(title="daily logins")
sns.barplot(x=month_counts.index, y=month_counts, order=['Jan', 'Feb', 'Mar', 'Apr'], ax=ax2).set(title="monthly logins")
sns.pointplot(x=hour_counts.index, y=hour_counts, ax=ax3).set(title="hourly logins");

# %% [markdown]
# Weekends have the highest logins, March logins are high until it steeps low during April. Based on hours, highest logins seem to pick up between 8 am to 11 am and picks up again from 5 pm to 11 pm.

# %% [markdown]
# ### 1.3.2 Most Logins by day

# %%
#getting average daily logins per hour
total_df = logins_df.groupby(["hour", "weekday"]).mean().reset_index()

#plotting df
fig, ax = plt.subplots(figsize=(20,7))
sns.lineplot(x="hour", y="logins", data=total_df, hue="weekday", ax=ax)\
    .set(title="Average Daily Logins per Hour", xticks=range(0,25))
ax.legend(loc="upper right", ncol=8);

# %% [markdown]
# It looks like usual demands - On weekends there are increase in logins during weekends as evident for Friday, Saturday, and Sunday (possibly late night outings) and peak demand during morning commute on weekdays.

# %% [markdown]
# # Part 2 ‐ Experiment and metrics design
# The neighboring cities of Gotham and Metropolis have complementary circadian rhythms: on weekdays, Ultimate Gotham is most active at night, and Ultimate Metropolis is most active during the day. On weekends, there is reasonable activity in both cities.
# However, a toll bridge, with a two­way toll, between the two cities causes driver partners to tend to be exclusive to each city. The Ultimate managers of city operations for the two cities have proposed an experiment to encourage driver partners to be available in both cities, by reimbursing all toll costs.
#
# 1. What would you choose as the key measure of success of this experiment in encouraging driver partners to serve both cities, and why would you choose this metric?
#
# **Response**: Since Ultimate managers are willing to reimburse for the toll costs. I would check the following if there is a relationship between management covering the toll costs and drivers' behavior. For instance, if its incentivize enough, we can assume that drivers will NOT be exclusive to one particular city during weekdays. We would check whether Gotham exclusive drivers will have increased transactions in Metropolis and vice versa.
#
# 2. Describe a practical experiment you would design to compare the effectiveness of the proposed change in relation to the key measure of success. Please provide details on:
#     - how you will implement the experiment
#         - **response**: We would do one-month experiment on drivers' behavior after enacting a program to cover toll costs for the drivers. We can measure based on transactions that details destinations (location).
#     - what statistical test(s) you will conduct to verify the significance of the
# observation
#         - **response**: We can conduct A/B test by comparing pre-toll and post-toll. I would also utilize ANOVA testing whether reimbursing toll cost are associated or not. Based on standard p-value cut off.
#         I'll be making decision whether to reject null hypothesis ($H_0$) or not based on standard p-value cutoff of 0.05 or 5%.
#
#     p-value < $\alpha$ (0.05) - Data providing significant evidence against the null hypothesis ($H_0$) and accept the alternate hypothesis ($H_a$). In other words, it is more than 95% likely that the association of interest would be present following repeated smaples drawn from the population.
#     p-value > $\alpha$ (0.05) - Data do not provide enough evidence against the null hypothesis ($H_0$)
#
#     - how you would interpret the results and provide recommendations to the city
# operations team along with any caveats.
#         - **response**: When it is statistically significant, we would know having toll reimbursement program affects drivers' behavior to be not exclusive to one city.
#             - Some potential caveats are - the test assumes drivers are willing to drive more than 12 or more hours a day. There may be some issues not accounting for drivers' personal schedule preference. For instance, Gotham drivers may have intentionally schedule around evening time and Metropolis drivers scheduled their drive hours during the day only due to perhaps cultural difference, so if that's the case toll reimbursement program may not matter much.

# %% [markdown]
# # Part 3. Predictive modeling

# %%
# Get logins file
user_df = pd.read_json('ultimate_data_challenge.json')
user_df.head(3)
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
#
#    avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 0        1.1     2014-06-17   iPhone       15.4                 True
# 1        1.0     2014-05-05  Android        0.0                False
# 2        1.0     2014-01-07   iPhone        0.0                False
#
#    weekday_pct  avg_dist  avg_rating_by_driver
# 0         46.2      3.67                   5.0
# 1         50.0      8.26                   5.0
# 2        100.0      0.77                   5.0

# %%
user_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    50000 non-null  object
#  1   trips_in_first_30_days  50000 non-null  int64
#  2   signup_date             50000 non-null  object
#  3   avg_rating_of_driver    41878 non-null  float64
#  4   avg_surge               50000 non-null  float64
#  5   last_trip_date          50000 non-null  object
#  6   phone                   49604 non-null  object
#  7   surge_pct               50000 non-null  float64
#  8   ultimate_black_user     50000 non-null  bool
#  9   weekday_pct             50000 non-null  float64
#  10  avg_dist                50000 non-null  float64
#  11  avg_rating_by_driver    49799 non-null  float64
# dtypes: bool(1), float64(6), int64(1), object(4)
# memory usage: 4.2+ MB

# %% [markdown]
# signup_date and last_trip_date should be in datetime format.

# %% [markdown]
# ## 3.1 Data Cleaning

# %%
# convert date-related columns to datetime format
user_df['last_trip_date'] = pd.to_datetime(user_df['last_trip_date'], format='%Y-%m-%d')
user_df['signup_date'] = pd.to_datetime(user_df['signup_date'], format='%Y-%m-%d')

# %%
user_df.isna().any()
# Out:
# city                      False
# trips_in_first_30_days    False
# signup_date               False
# avg_rating_of_driver       True
# avg_surge                 False
# last_trip_date            False
# phone                      True
# surge_pct                 False
# ultimate_black_user       False
# weekday_pct               False
# avg_dist                  False
# avg_rating_by_driver       True
# dtype: bool

# %% [markdown]
# Three columns containing NaN columns

# %%
user_df[user_df.isna().any(axis=1)]['phone']
# Out:
# 6        Android
# 9        Android
# 12        iPhone
# 14       Android
# 15       Android
#           ...
# 49984    Android
# 49985    Android
# 49989     iPhone
# 49996     iPhone
# 49999    Android
# Name: phone, Length: 8555, dtype: object

# %%
# Replacing NaN values in phone column with 'other'
user_df['phone'].fillna('other', inplace=True)

# %%
user_df[user_df.isna().any(axis=1)].head()
# Out:
#           city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 6      Astapor                       1  2014-01-24                   NaN
# 9   Winterfell                       1  2014-01-03                   NaN
# 12  Winterfell                       1  2014-01-15                   NaN
# 14     Astapor                       1  2014-01-27                   NaN
# 15  Winterfell                       1  2014-01-15                   NaN
#
#     avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 6         1.0     2014-01-25  Android        0.0                False
# 9         1.0     2014-01-05  Android        0.0                False
# 12        1.0     2014-03-12   iPhone        0.0                False
# 14        1.0     2014-01-28  Android        0.0                False
# 15        1.0     2014-01-16  Android        0.0                 True
#
#     weekday_pct  avg_dist  avg_rating_by_driver
# 6         100.0      3.95                   4.0
# ...

# %% [markdown]
# For the purposes of finding active user (taken at least one trip during its first 30 days). The NaNs values in average rating of driver, average rating by driver and phone columns does not really affect the user active status. Furthermore, it may be because drivers hasn't been rated by the users and record of user's phone type is not inputted as of yet.

# %% [markdown]
# ## 3.2 EDA

# %%
'''
Computing the cutoff time to determne user retention - user is considered retained if user took a trip within 
30 days prior to 7/01/2014.
'''

# Cutoff time for determing user retention
cutoff = user_df['last_trip_date'].max() - pd.Timedelta('30 days')

# determine if a user is retained based on the cutoff time
user_df['retained'] = user_df['last_trip_date'].apply(lambda x: True if x >= cutoff else False)


# compute the fraction of user retained
user_df['retained'].sum()/len(user_df)
# Out:
# 0.37608

# %% [markdown]
# 37% of users are retained six months later

# %% [markdown]
# ### 3.2.1 Identifying correlation between user retention with categorical columns

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(20,4))
sns.countplot(x='phone', data=user_df, hue='retained', ax=ax1).set(title="phone and retention")
sns.countplot(x='city', data=user_df, hue='retained', ax=ax2).set(title="city and user retention")
sns.countplot(x='ultimate_black_user', data=user_df, hue='retained', ax=ax3).set(title='ultimate black and user retention');

# %%
sns.heatmap(user_df.corr(),annot=True);

# %% [markdown]
# Avg_rating_by_driver and avg_rating_of_driver columns has minimal correlation with retained column. Therefore, NaNs will be replaced with median values.

# %%
# impute missing values in 'avg_rating_by_driver' and 'avg_rating_of_driver' columns
user_df['avg_rating_by_driver'].fillna(user_df['avg_rating_by_driver'].median(), inplace=True)
user_df['avg_rating_of_driver'].fillna(user_df['avg_rating_of_driver'].median(), inplace=True)

# %% [markdown]
# **key findings:**
# - iPhone users has highest retention rate.
# - Winterfell city has highest retention rate.
# - User being ulimate black user contributes to user being retained.
# - Being ultimate black user and taking trips within first 30 days have highest correlation with user retention status.

# %% [markdown]
# ## 3.3 Model Building
# Since this is a classification problem, I'll be using three classifiers: Random Forest, Gradient Boosting, and AdaBoost.

# %%
# Machine learning
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVC
from sklearn import metrics

# %%
user_df.columns
# Out:
# Index(['city', 'trips_in_first_30_days', 'signup_date', 'avg_rating_of_driver',
#        'avg_surge', 'last_trip_date', 'phone', 'surge_pct',
#        'ultimate_black_user', 'weekday_pct', 'avg_dist',
#        'avg_rating_by_driver', 'retained'],
#       dtype='object')

# %%
user_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    50000 non-null  object
#  1   trips_in_first_30_days  50000 non-null  int64
#  2   signup_date             50000 non-null  datetime64[ns]
#  3   avg_rating_of_driver    50000 non-null  float64
#  4   avg_surge               50000 non-null  float64
#  5   last_trip_date          50000 non-null  datetime64[ns]
#  6   phone                   50000 non-null  object
#  7   surge_pct               50000 non-null  float64
#  8   ultimate_black_user     50000 non-null  category
#  9   weekday_pct             50000 non-null  float64
#  10  avg_dist                50000 non-null  float64
#  11  avg_rating_by_driver    50000 non-null  float64
#  12  retained                50000 non-null  category
# ...

# %% [markdown]
# ### 3.3.1 Random Forest

# %%
user_df["ultimate_black_user"] = user_df["ultimate_black_user"].map({False:0, True:1}).astype("category")
user_df["retained"] = user_df["retained"].map({False:0, True:1}).astype("category")

# %%
# Create X (features) and y (response)
X = pd.get_dummies(user_df.drop('retained',axis=1), drop_first=True)
y = user_df['retained']

X.head(2)
# Out:
#    trips_in_first_30_days  avg_rating_of_driver  avg_surge  surge_pct  \
# 0                       4                   4.7        1.1       15.4
# 1                       0                   5.0        1.0        0.0
#
#    weekday_pct  avg_dist  avg_rating_by_driver  city_King's Landing  \
# 0         46.2      3.67                   5.0                    1
# 1         50.0      8.26                   5.0                    0
#
#    city_Winterfell  phone_iPhone  phone_other  ultimate_black_user_1
# 0                0             1            0                      1
# 1                0             0            0                      0

# %%
# train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# %%
X_train
# Out:
#        trips_in_first_30_days  avg_rating_of_driver  avg_surge  surge_pct  \
# 2089                        0                   4.9       1.00        0.0
# 47112                       1                   4.9       1.00        0.0
# 20504                       0                   4.9       1.00        0.0
# 22047                       1                   4.3       1.02       10.0
# 15915                       1                   5.0       1.00        0.0
# ...                       ...                   ...        ...        ...
# 16695                       0                   4.6       1.15       40.0
# 4363                        7                   3.9       1.11       14.3
# 42110                       1                   5.0       1.00        0.0
# 35265                       3                   5.0       1.00        0.0
# 23510                       0                   5.0       1.00        0.0
#
#        weekday_pct  avg_dist  avg_rating_by_driver  city_King's Landing  \
# ...

# %%
rf = Pipeline([('scaler', StandardScaler()),('rf', RandomForestClassifier(class_weight='balanced'))]) # set class_weight='balanced' to adjust for the imbalanced classes
rf.fit(X_train, y_train)
pred_train = rf.predict(X_train)
pred_test = rf.predict(X_test)

# %%
metrics.accuracy_score(y_train, pred_train)
# Out:
# 0.9967733333333333

# %%
metrics.accuracy_score(y_test, pred_test)
# Out:
# 0.75912

# %%
metrics.f1_score(y_train, pred_train)
# Out:
# 0.9957081545064378

# %%
metrics.f1_score(y_test, pred_test)
# Out:
# 0.673321037213844

# %%
# Grid search of parameters n_estimators and max_features to improve GradientBoostingClassifer model
parameters = {"rf__n_estimators" : [75, 100, 150], "rf__max_depth" : [5, 10, 15]}
rf_cv = GridSearchCV(rf, parameters, scoring='accuracy', cv=5)
rf_cv.fit(X_train, y_train)
print('Best parameters:', rf_cv.best_params_)
print('Corresponding accuracy score:', rf_cv.best_score_)
# Out:
# Best parameters: {'rf__max_depth': 10, 'rf__n_estimators': 100}
# Corresponding accuracy score: 0.7763733333333334

# %%
# updated GradientBoostingClassifier model with the optimized parameter
rf = Pipeline([('scaler', StandardScaler()),('rf', RandomForestClassifier(class_weight='balanced', n_estimators = 100, max_depth=10))])
rf.fit(X_train, y_train)
pred_train = rf.predict(X_train)
pred_test = rf.predict(X_test)

# %%
metrics.accuracy_score(y_train, pred_train)
# Out:
# 0.8050133333333334

# %%
metrics.accuracy_score(y_test, pred_test)
# Out:
# 0.78008

# %%
metrics.f1_score(y_test, pred_test)
# Out:
# 0.7172683328190889

# %%
# feature importance ranking from the optimized GradientBoostingClassifier 
feature_rank = pd.DataFrame({'feature': X_train.columns, 'importance': rf.named_steps.rf.feature_importances_})
print(feature_rank.sort_values(by='importance',ascending=False))
# Out:
#                    feature  importance
# 6     avg_rating_by_driver    0.189077
# 7      city_King's Landing    0.143472
# 3                surge_pct    0.125427
# 4              weekday_pct    0.124230
# 2                avg_surge    0.091458
# 9             phone_iPhone    0.078896
# 0   trips_in_first_30_days    0.072902
# 5                 avg_dist    0.061336
# 11   ultimate_black_user_1    0.055830
# 1     avg_rating_of_driver    0.039053
# 8          city_Winterfell    0.016169
# 10             phone_other    0.002151

# %% [markdown]
# ### 3.3.2 Client Recommendation

# %% [markdown]
# 1. More marketing campaign or offering incentives in cities like Astapo and Winterfell since retention rate was lower than King's land.
# 2. Look more into why iPhone users have higher retention rate than other Androids, perhaps user is experiencing odd UI/UX compared to iPhone users.
